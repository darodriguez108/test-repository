# %%
import numpy as np
import pandas as pd
import xlrd
import os
import tarfile
from six.moves import urllib
import seaborn as sns

# %%
pre = os.path.dirname(os.path.realpath('__file__'))
fname = 'DataFile1.xlsx'
path = os.path.join(pre, fname)
data = pd.read_excel(path)

# %%
data.head()
# Out:
#      Range     HITF/RHTL # Shot #  Shot Date Program  \
# 0  .50 Cal  RHTL 18URO 055   1842 2017-10-30     URO
# 1  .50 Cal           17543   1841 2017-10-27     CCP
# 2  .50 Cal  RHTL 18URO 054   1840 2017-10-26     URO
# 3  .50 Cal           17276   1839 2017-10-25     CCP
# 4  .50 Cal           17544   1837 2017-10-24     CCP
#
#                                               Series Series Test #  \
# 0              Europa Clipper Propulsion Module Test     5.1.1.4-3
# 1  SpaceX Dragon 2 HVI Test Program: LOC BL Asses...            94
# 2              Europa Clipper Propulsion Module Test     5.3.1.2-5
# 3  SpaceX Dragon 2 HVI Test Program: LOC BL Asses...            12
# 4  SpaceX Dragon 2 HVI Test Program: LOC BL Asses...            95
#
#    Desired Velocity  Actual Velocity  Delta Velocity   ...    Barrel  \
# 0               7.0             6.96           -0.04   ...        18
# 1               7.0             6.93           -0.07   ...        18
# 2               7.0             6.98           -0.02   ...        18
# 3               7.0             6.93           -0.07   ...        18
# 4               7.0             7.06            0.06   ...        11
#
#    Petal Valve Accept / Unaccept Reason If Unaccept   ES  \
# 0  10k 304l ss        Acceptable                 NaN NaN
# 1  10k 304l ss        Acceptable                 NaN NaN
# 2  10k 304l ss        Acceptable                 NaN NaN
# 3  10k 304l ss        Acceptable                 NaN NaN
# 4  10k 304l ss        Acceptable                 NaN NaN
#
#                   Sabot Material Sabot OD Sabot Depth Count  Muzzle
# 0  4 piece lexan rear serrations   0.4945           6     1  0.4887
# 1  4 piece lexan rear serrations   0.4945           6     1  0.4887
# 2  4 piece lexan rear serrations   0.4940         6.5     1  0.4887
# 3  4 piece lexan rear serrations   0.4940        6.25     1  0.4887
# 4  4 piece lexan rear serrations   0.5520         n/a     1  0.5418
#
# [5 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1114 entries, 0 to 1113
# Data columns (total 25 columns):
# Range                  1114 non-null object
# HITF/RHTL #            952 non-null object
# Shot #                 1114 non-null object
# Shot Date              1114 non-null datetime64[ns]
# Program                957 non-null object
# Series                 154 non-null object
# Series Test #          153 non-null object
# Desired Velocity       1114 non-null float64
# Actual Velocity        1108 non-null float64
# Delta Velocity         1109 non-null float64
# Powder                 1114 non-null float64
# Lp Mass                1114 non-null float64
# Projectile             1114 non-null object
# Projectile Material    1114 non-null object
# Projectile Mass        105 non-null float64
# Barrel                 1114 non-null int64
# Petal Valve            1103 non-null object
# Accept / Unaccept      1109 non-null object
# Reason If Unaccept     31 non-null object
# ES                     38 non-null float64
# Sabot Material         105 non-null object
# Sabot OD               1107 non-null float64
# Sabot Depth            1107 non-null object
# Count                  1114 non-null int64
# Muzzle                 947 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(13)
# memory usage: 217.7+ KB

# %%
data.drop('Count', axis=1, inplace=True)

# %%
data.describe()
# Out:
#        Desired Velocity  Actual Velocity  Delta Velocity       Powder  \
# count       1114.000000      1108.000000     1109.000000  1114.000000
# mean           6.350171         6.300523       -0.051912   169.469937
# std            1.199016         1.272615        0.532167    43.494511
# min            2.500000         0.000000       -6.800000    53.700000
# 25%            6.730000         6.420000       -0.100000   161.500000
# 50%            7.000000         6.880000        0.010000   185.350000
# 75%            7.000000         7.030000        0.100000   198.300000
# max            8.000000         7.550000        2.560000   235.000000
#
#            Lp Mass  Projectile Mass       Barrel    ES     Sabot OD  \
# count  1114.000000       105.000000  1114.000000  38.0  1107.000000
# mean      2.290578         0.295259     7.421005   2.0     1.307439
# std       0.601881         0.396319     3.637376   0.0    23.360387
# min       0.000000         0.010740     2.000000   2.0     0.000000
# 25%       1.977080         0.042680     5.000000   2.0     0.512000
# 50%       2.238575         0.127700     7.000000   2.0     0.532000
# 75%       2.559525         0.374660    10.000000   2.0     0.557500
# max       4.185200         1.614860    18.000000   2.0   777.600000
#
#            Muzzle
# count  947.000000
# mean     0.524244
# std      0.025536
# min      0.487000
# 25%      0.500500
# 50%      0.522000
# 75%      0.546000
# max      0.590700

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
# data.hist(bins=50, figsize=(20,15))
# plt.show()

# %%
corr_matrix = data.corr()

corr_matrix["Actual Velocity"].sort_values(ascending=False)
# Out:
# Actual Velocity     1.000000
# Desired Velocity    0.922412
# Powder              0.858615
# Delta Velocity      0.335355
# Barrel              0.115588
# Muzzle              0.092683
# Sabot OD            0.021651
# Lp Mass             0.000700
# Projectile Mass    -0.061426
# ES                       NaN
# Name: Actual Velocity, dtype: float64

# %%
s = data["Sabot Depth"].convert_objects(convert_numeric=True).dropna()
data['sabot_od'] = pd.to_numeric(data['Sabot OD'], errors='coerce')

#pd.to_numeric(data["Sabot Depth"])
# Out:
# C:\Users\drodri18\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.

# %%
data["Sabot Depth"] = s
data.dropna(subset=["Sabot Depth"],inplace=True)
data.dropna(subset=["sabot_od"],inplace=True)
# special = df[df.kind=='special']
# others = df[df.kind!='special']

# special = special.dropna(how='any')

# %%
data["Sabot_OD"] = data[(data['sabot_od']>0.4) & (data['sabot_od']<0.6)]['sabot_od']
data["Actual_Velocity"] = data[(data['Actual Velocity']>3.8) & (data['sabot_od']< 8.0)]['Actual Velocity']
data["Delta_Velocity"] = data[(data['Delta Velocity']> -0.3) & (data['Delta Velocity']< 0.3)]['Delta Velocity']
data.drop('Actual Velocity', axis=1,inplace=True)
data.drop('Delta Velocity', axis=1,inplace=True)
data.drop('Sabot OD', axis=1,inplace=True)
data.drop('sabot_od', axis=1,inplace=True)
data.drop('Range', axis=1,inplace=True)
data.drop('Projectile', axis=1,inplace=True)
data.drop('Projectile Material', axis=1,inplace=True)
data.drop('Accept / Unaccept', axis=1,inplace=True)
data.drop('Reason If Unaccept ', axis=1,inplace=True)
data.drop('Shot Date', axis=1,inplace=True)
#data.drop('Barrel', axis=1,inplace=True)
data.drop('ES', axis=1,inplace=True)
data.drop('HITF/RHTL #', axis=1,inplace=True)
data.drop('Projectile Mass', axis=1,inplace=True)
data.drop('Shot #', axis=1,inplace=True)
data.drop('Program', axis=1,inplace=True)
data.drop('Series', axis=1,inplace=True)
data.drop('Series Test #', axis=1,inplace=True)
data.drop('Petal Valve', axis=1,inplace=True)
data.drop('Sabot Material', axis=1,inplace=True)
data.dropna(subset=["Muzzle"],inplace=True)
data.dropna(subset=["Sabot_OD"],inplace=True)
data.dropna(subset=["Actual_Velocity"],inplace=True)
data.dropna(subset=["Delta_Velocity"],inplace=True)
data["SabotOD-Muzzle*Insertion Depth"]= (data["Sabot_OD"]-data["Muzzle"])*data["Sabot Depth"]
data["Powder-(SabotOD-Muzzle*Insertion Depth)"]=data["Powder"]-data["SabotOD-Muzzle*Insertion Depth"]
data
# Out:
#       Desired Velocity  Powder  Lp Mass  Barrel  Sabot Depth  Muzzle  \
# 0                  7.0   161.5  1.15050      18       6.0000  0.4887
# 1                  7.0   160.0  1.00404      18       6.0000  0.4887
# 2                  7.0   161.0  1.14960      18       6.5000  0.4887
# 3                  7.0   175.5  1.78716      18       6.2500  0.4887
# 7                  7.0   167.2  1.40644      11       5.7500  0.5418
# 8                  7.0   186.0  1.93079      11       5.2500  0.5418
# 9                  7.0   179.0  1.86024      11       5.7500  0.5418
# 10                 7.0   172.0  1.67120      11       5.5000  0.5418
# 14                 7.0   166.5  1.47850      11       5.5000  0.5418
# 15                 7.0   171.0  1.63380      11       5.5000  0.5418
# 16                 7.0   186.0  1.94070      11       6.5000  0.5418
# 17                 7.0   177.3  1.83820      11       6.0000  0.5418
# 18                 7.0   178.0  1.83410      11       5.6250  0.5418
# 19                 7.0   193.0  2.19350      11       5.2500  0.5418
# 20                 7.0   171.0  1.66810      11       5.5000  0.5418
# 21                 7.0   166.8  1.38677      18       5.2500  0.4887
# 22                 7.0   165.0  1.15820      15       5.2500  0.4965
# 23                 7.0   162.0  1.14814      18       6.0000  0.4887
# 24                 7.0   165.0  1.19652      18       6.0000  0.4887
# 26                 7.0   157.8  1.03535      18       6.0000  0.4887
# 27                 7.0   184.0  1.76350      15       4.2500  0.4965
# 28                 7.0   165.0  1.43000      18       6.0000  0.4887
# 29                 4.0    80.5  1.21295      18       5.2500  0.4887
# 31                 7.0   158.0  1.16033      18       5.7500  0.4887
# 32                 7.0   160.0  1.15269      18       6.0000  0.4887
# 33                 7.0   158.0  1.14516      18       5.5000  0.4887
# 34                 7.0   158.0  1.02990      18       6.2500  0.4887
# 35                 7.0   169.0  1.63121      18       6.0000  0.4887
# 36                 7.0   169.0  1.63157      18       5.7500  0.4887
# 37                 4.0    77.0  1.19956      18       4.2500  0.4887
# ...                ...     ...      ...     ...          ...     ...
# 1016               6.8   175.0  2.49520       6       1.5000  0.5230
# 1017               6.8   167.0  1.99800       6       1.7500  0.5230
# 1019               6.8   172.0  2.20000       6       1.2500  0.5230
# 1020               6.8   176.0  2.41200       6       3.6250  0.5230
# 1021               5.0   105.0  2.10800       6       6.0000  0.5230
# 1022               7.0   175.0  2.10000       6       3.7500  0.5230
# 1024               7.0   175.0  2.10400       6       2.7500  0.5230
# 1025               7.0   176.0  2.10800       6       2.0000  0.5230
# 1026               4.5    96.0  2.11000       6       2.2500  0.5230
# 1027               6.8   175.0  2.36000       6       5.2500  0.5230
# 1030               4.5    96.0  2.17400       6       3.2500  0.5230
# 1031               4.5    96.0  2.03000       6       5.2500  0.5230
# 1032               6.8   175.0  2.14000       6       2.7500  0.5230
# 1042               7.0   183.0  2.20000       6       1.5000  0.5230
# 1057               4.5    96.0  2.06298       6       2.0000  0.4905
# 1058               4.5    98.0  2.05502       6       2.2500  0.4905
# 1059               6.8   193.0  2.93815       6       2.0000  0.4905
# 1060               6.8   171.0  2.05259       6       1.2500  0.4905
# 1061               6.8   184.0  2.51906       6       2.5000  0.4905
# 1062               6.8   187.0  2.82075       6       2.0000  0.4905
# 1064               4.5    94.0  2.03024       6       1.2500  0.4905
# 1065               6.8   175.0  2.01729       6       2.0000  0.4905
# 1066               6.8   184.0  2.55158       6       2.5000  0.4905
# 1067               6.8   187.0  2.77259       6       3.0000  0.4905
# 1068               6.8   180.0  2.05325       6       4.0000  0.4905
# 1069               6.8   186.0  2.14296       6       3.0000  0.4905
# 1070               6.8   180.0  1.98763       6       2.0000  0.4905
# 1071               6.8   175.0  2.06000       6       1.2500  0.4905
# 1091               6.8   182.0  2.03290       6       1.5781  0.5060
# 1092               6.8   180.0  0.00000       6       0.7500  0.5060
#
#       Sabot_OD  Actual_Velocity  Delta_Velocity  \
# 0       0.4945             6.96           -0.04
# 1       0.4945             6.93           -0.07
# 2       0.4940             6.98           -0.02
# 3       0.4940             6.93           -0.07
# 7       0.5520             6.90           -0.10
# 8       0.5515             7.11            0.11
# 9       0.5515             7.05            0.05
# 10      0.5515             7.05            0.05
# 14      0.5510             6.99           -0.01
# 15      0.5510             6.99           -0.01
# 16      0.5500             7.04            0.04
# 17      0.5500             6.97           -0.03
# 18      0.5500             7.06            0.06
# 19      0.5500             7.02            0.02
# 20      0.5500             6.97           -0.03
# 21      0.4935             6.96           -0.04
# 22      0.4965             7.03            0.03
# 23      0.4935             6.96           -0.04
# 24      0.4935             7.11            0.11
# 26      0.4930             6.70           -0.30
# 27      0.4965             7.00            0.00
# 28      0.4930             6.92           -0.08
# 29      0.4930             3.88           -0.12
# 31      0.4925             7.00            0.00
# 32      0.4925             7.09            0.09
# 33      0.4925             7.07            0.07
# 34      0.4925             7.11            0.11
# 35      0.4920             7.03            0.03
# 36      0.4920             7.01            0.01
# 37      0.4920             3.93           -0.07
# ...        ...              ...             ...
# 1016    0.5320             6.86            0.06
# 1017    0.5320             7.03            0.23
# 1019    0.5305             6.92            0.12
# 1020    0.5305             6.94            0.14
# 1021    0.5285             5.04            0.04
# 1022    0.5295             7.09            0.09
# 1024    0.5285             6.90           -0.10
# 1025    0.5280             7.07            0.07
# 1026    0.5280             4.39           -0.11
# 1027    0.5275             6.88            0.08
# 1030    0.5270             4.44           -0.06
# 1031    0.5260             4.35           -0.15
# 1032    0.5260             7.07            0.27
# 1042    0.5265             7.07            0.07
# 1057    0.5215             4.57            0.07
# 1058    0.5210             4.79            0.29
# 1059    0.5205             6.72           -0.08
# 1060    0.5200             6.76           -0.04
# 1061    0.5190             6.79           -0.01
# 1062    0.5180             6.80            0.00
# 1064    0.5175             4.28           -0.22
# 1065    0.5165             7.02            0.22
# 1066    0.5155             6.93            0.13
# 1067    0.5145             6.86            0.06
# 1068    0.5130             7.10            0.30
# 1069    0.5120             6.96            0.16
# 1070    0.5120             6.86            0.06
# 1071    0.5120             6.53           -0.27
# 1091    0.5115             6.96            0.16
# 1092    0.5115             6.66           -0.14
#
#       SabotOD-Muzzle*Insertion Depth  Powder-(SabotOD-Muzzle*Insertion Depth)
# 0                           0.034800                               161.465200
# 1                           0.034800                               159.965200
# 2                           0.034450                               160.965550
# 3                           0.033125                               175.466875
# 7                           0.058650                               167.141350
# 8                           0.050925                               185.949075
# 9                           0.055775                               178.944225
# 10                          0.053350                               171.946650
# 14                          0.050600                               166.449400
# 15                          0.050600                               170.949400
# 16                          0.053300                               185.946700
# 17                          0.049200                               177.250800
# 18                          0.046125                               177.953875
# 19                          0.043050                               192.956950
# 20                          0.045100                               170.954900
# 21                          0.025200                               166.774800
# 22                          0.000000                               165.000000
# 23                          0.028800                               161.971200
# 24                          0.028800                               164.971200
# 26                          0.025800                               157.774200
# 27                          0.000000                               184.000000
# 28                          0.025800                               164.974200
# 29                          0.022575                                80.477425
# 31                          0.021850                               157.978150
# 32                          0.022800                               159.977200
# 33                          0.020900                               157.979100
# 34                          0.023750                               157.976250
# 35                          0.019800                               168.980200
# 36                          0.018975                               168.981025
# 37                          0.014025                                76.985975
# ...                              ...                                      ...
# 1016                        0.013500                               174.986500
# 1017                        0.015750                               166.984250
# 1019                        0.009375                               171.990625
# 1020                        0.027187                               175.972813
# 1021                        0.033000                               104.967000
# 1022                        0.024375                               174.975625
# 1024                        0.015125                               174.984875
# 1025                        0.010000                               175.990000
# 1026                        0.011250                                95.988750
# 1027                        0.023625                               174.976375
# 1030                        0.013000                                95.987000
# 1031                        0.015750                                95.984250
# 1032                        0.008250                               174.991750
# 1042                        0.005250                               182.994750
# 1057                        0.062000                                95.938000
# 1058                        0.068625                                97.931375
# 1059                        0.060000                               192.940000
# 1060                        0.036875                               170.963125
# 1061                        0.071250                               183.928750
# 1062                        0.055000                               186.945000
# 1064                        0.033750                                93.966250
# 1065                        0.052000                               174.948000
# 1066                        0.062500                               183.937500
# 1067                        0.072000                               186.928000
# 1068                        0.090000                               179.910000
# 1069                        0.064500                               185.935500
# 1070                        0.043000                               179.957000
# 1071                        0.026875                               174.973125
# 1091                        0.008680                               181.991320
# 1092                        0.004125                               179.995875
#
# [779 rows x 11 columns]

# %%
data.dropna(subset=["Powder-(SabotOD-Muzzle*Insertion Depth)"],inplace=True)

#sabot_od = data[(data['Sabot OD']> 0.4) & (data['Sabot OD']<0.6)]

# sabot_od1 = data[data['Sabot_od']> 0.4]
# sabot_od1
# data['Sabot OD_'] = sabot_od1
#data[['Powder','Powder-(SabotOD-Muzzle*Insertion Depth)']]

# %%
corr_matrix = data.corr()

corr_matrix["Actual_Velocity"].sort_values(ascending=False)
# Out:
# Actual_Velocity                            1.000000
# Desired Velocity                           0.989363
# Powder-(SabotOD-Muzzle*Insertion Depth)    0.902666
# Powder                                     0.902637
# Sabot_OD                                   0.170727
# Muzzle                                     0.161828
# Delta_Velocity                             0.100805
# Sabot Depth                                0.093961
# SabotOD-Muzzle*Insertion Depth             0.090268
# Barrel                                     0.058398
# Lp Mass                                    0.014255
# Name: Actual_Velocity, dtype: float64

# %%
corr_matrix = data.corr()

corr_matrix["Powder"].sort_values(ascending=False)
# Out:
# Powder                                     1.000000
# Powder-(SabotOD-Muzzle*Insertion Depth)    1.000000
# Desired Velocity                           0.916414
# Actual_Velocity                            0.902637
# Lp Mass                                    0.342201
# Sabot_OD                                   0.286012
# Muzzle                                     0.270317
# SabotOD-Muzzle*Insertion Depth             0.142108
# Sabot Depth                                0.126346
# Barrel                                    -0.066735
# Delta_Velocity                            -0.068903
# Name: Powder, dtype: float64

# %%
attributes = ["Actual_Velocity", "Powder", "Powder-(SabotOD-Muzzle*Insertion Depth)"]

scatter_matrix(data[attributes], figsize=(12,8))
# Out:
# C:\Users\drodri18\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020DA619D2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DA655E748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DA65B7F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020DA6610F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DA663C128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DA663C3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020DA66EE898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DA67A23C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DA67AAF60>]], dtype=object)

# %%
sns.lmplot(x='Powder-(SabotOD-Muzzle*Insertion Depth)', y='Actual_Velocity',data=data, col='Barrel', size=3, fit_reg=False)

# %%
writer = pd.ExcelWriter('CleanData.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
data.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
